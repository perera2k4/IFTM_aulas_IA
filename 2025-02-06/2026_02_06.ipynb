# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
dados = {
    "horas_estudo": [1,2,3,4,5,6,7,8],
    "faltas": [15,14,10,8,6,4,2,1],
    "nota": [3,4,5,6,6.5,7.5,8.5,9]
}

df = pd.DataFrame(dados)
df
# Out:
#    horas_estudo  faltas  nota
# 0             1      15   3.0
# 1             2      14   4.0
# 2             3      10   5.0
# 3             4       8   6.0
# 4             5       6   6.5
# 5             6       4   7.5
# 6             7       2   8.5
# 7             8       1   9.0

# %%
df.head(6) # Exibe as primeiras linhas do DataFrame
# Out:
#    horas_estudo  faltas  nota
# 0             1      15   3.0
# 1             2      14   4.0
# 2             3      10   5.0
# 3             4       8   6.0
# 4             5       6   6.5
# 5             6       4   7.5

# %%
df.tail() # Exibe as ultimas linhas do DataFrame
# Out:
#    horas_estudo  faltas  nota
# 3             4       8   6.0
# 4             5       6   6.5
# 5             6       4   7.5
# 6             7       2   8.5
# 7             8       1   9.0

# %%
df.info() # Exibe informações dao DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   horas_estudo  8 non-null      int64
#  1   faltas        8 non-null      int64
#  2   nota          8 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 324.0 bytes

# %%
df.describe() # Exibe informações estatísticas sobre o DataFrame
# Out:
#        horas_estudo     faltas      nota
# count       8.00000   8.000000  8.000000
# mean        4.50000   7.500000  6.187500
# std         2.44949   5.237229  2.120268
# min         1.00000   1.000000  3.000000
# 25%         2.75000   3.500000  4.750000
# 50%         4.50000   7.000000  6.250000
# 75%         6.25000  11.000000  7.750000
# max         8.00000  15.000000  9.000000

# %%
plt.scatter(df["horas_estudo"], df["nota"])
plt.xlabel("Horas de estudo")
plt.ylabel("Notas")
plt.show()

# %%
df.corr() # Exibe a correlação entre as variáveis do DataFrame
# Out:
#               horas_estudo    faltas      nota
# horas_estudo      1.000000 -0.991094  0.997111
# faltas           -0.991094  1.000000 -0.993821
# nota              0.997111 -0.993821  1.000000

# %%
plt.scatter(df["faltas"], df["nota"])
plt.xlabel("Nº de faltas")
plt.ylabel("Notas")
plt.show()
