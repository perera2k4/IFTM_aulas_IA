# %%
# Importando as bibliotecas
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from numpy import int64
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar o dataset
df = pd.read_csv('dataset_emprestimo_aprovacao.csv')

# %%
# Selecionar as colunas de interesse
df = df[['renda_mensal', 'score_credito', 'dividas_ativas', 'emprestimo_aprovado']]

# %%
# Definir as variáveis de entrada e saída
x = df.drop(['emprestimo_aprovado'], axis=1)
y = df['emprestimo_aprovado']

# %%
# Serapar em conjuntos de treinamento e teste
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.3,
    random_state=42
)

# %%
# Padronizar os dados
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Treinar o modelo de regressão logística
modelo = KNeighborsClassifier(n_neighbors=5)
modelo.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Fazer as previsões
y_pred = modelo.predict(x_test_scaled)

# %%
# Avaliação do modelo
print('Matriz de confusão')
print(confusion_matrix(y_test, y_pred))

print('\nAcurácia')
print(accuracy_score(y_test, y_pred))

print('\nRelatório de classificação')
print(classification_report(y_test, y_pred))
# Out:
# Matriz de confusão
# [[ 1  6]
#  [ 1 22]]
#
# Acurácia
# 0.7666666666666667
#
# Relatório de classificação
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22         7
#            1       0.79      0.96      0.86        23
#
#     accuracy                           0.77        30
#    macro avg       0.64      0.55      0.54        30
# weighted avg       0.72      0.77      0.71        30

# %%
# Testar com diferentes valores de K
print("K Acurácia")
for k in range(1, 20):
    modelo_teste = KNeighborsClassifier(n_neighbors=k)
    modelo_teste.fit(x_train_scaled, y_train)
    y_pred_teste = modelo_teste.predict(x_test_scaled)
    print(f"{k}: Acurácia: {accuracy_score(y_test, y_pred_teste):.4f}")
# Out:
# K Acurácia
# 1: Acurácia: 0.7333
# 2: Acurácia: 0.7333
# 3: Acurácia: 0.8333
# 4: Acurácia: 0.8333
# 5: Acurácia: 0.7667
# 6: Acurácia: 0.7667
# 7: Acurácia: 0.8000
# 8: Acurácia: 0.7667
# 9: Acurácia: 0.7667
# 10: Acurácia: 0.7667
# 11: Acurácia: 0.7667
# 12: Acurácia: 0.7667
# 13: Acurácia: 0.7667
# 14: Acurácia: 0.7667
# 15: Acurácia: 0.7667
# 16: Acurácia: 0.7667
# 17: Acurácia: 0.7667
# 18: Acurácia: 0.7667
# 19: Acurácia: 0.7667

# %%
# Testar a simulação da aprovação de emprestimo
cliente_teste_aprovado = np.array([[1200, 800, 3]])

cliente_teste_aprovado_scaled = scaler.transform(cliente_teste_aprovado)
previsao = modelo.predict(cliente_teste_aprovado_scaled)

if previsao[0] == 1:
    print("Resultado da Previsão: Aprovado")
else:
    print("Resultado da Previsão: Reprovado")
# Out:
# Resultado da Previsão: Aprovado
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Testar a simulação da reprovação de emprestimo
cliente_teste_reprovado = np.array([[1200, 686, 3]])

cliente_teste_reprovado_scaled = scaler.transform(cliente_teste_reprovado)
previsao = modelo.predict(cliente_teste_reprovado_scaled)

if previsao[0] == 1:
    print("Resultado da Previsão: Aprovado")
else:
    print("Resultado da Previsão: Reprovado")
# Out:
# Resultado da Previsão: Reprovado
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Análise do modelo
# A acurácia do modelo é boa, mas se fosse treinada com uma base de dados mais volumosa e diversa poderia aumentar % de acurácia
