# %%
import pandas as pd
import warnings
from mlxtend.frequent_patterns import apriori, association_rules
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Carregar o dataset
df = pd.read_csv("basket.csv")

# Removendo a coluna transacao
df = df.drop(columns=["transacao"])

# %%
# Algoritm Apriori
frequent_itemsets = apriori(
    df,
    min_support=0.2,
    use_colnames=True
)

print("Sub-conjuntos frequentes:")
print(frequent_itemsets.sort_values(by="support", ascending=False))
# Out:
# Sub-conjuntos frequentes:
#     support                 itemsets
# 0      0.40                    (pao)
# 2      0.40                   (cafe)
# 1      0.35                  (leite)
# 3      0.30                 (acucar)
# 9      0.30              (pao, cafe)
# 13     0.30           (acucar, cafe)
# 5      0.25                 (feijao)
# 6      0.25                (cerveja)
# 8      0.25             (pao, leite)
# 4      0.25                  (arroz)
# 14     0.25          (arroz, feijao)
# 11     0.25            (cafe, leite)
# 7      0.20           (refrigerante)
# 10     0.20            (acucar, pao)
# 12     0.20          (acucar, leite)
# 15     0.20  (refrigerante, cerveja)
# 16     0.20      (acucar, pao, cafe)
# 17     0.20    (acucar, cafe, leite)

# %%
# Gerar regras de associação
rules = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=0.6
)

print("Regras de associação")
print(rules)
# Out:
# Regras de associação
#         antecedents     consequents  antecedent support  consequent support  \
# 0             (pao)         (leite)                0.40                0.35
# 1           (leite)           (pao)                0.35                0.40
# 2             (pao)          (cafe)                0.40                0.40
# 3            (cafe)           (pao)                0.40                0.40
# 4          (acucar)           (pao)                0.30                0.40
# 5            (cafe)         (leite)                0.40                0.35
# 6           (leite)          (cafe)                0.35                0.40
# 7          (acucar)         (leite)                0.30                0.35
# 8          (acucar)          (cafe)                0.30                0.40
# 9            (cafe)        (acucar)                0.40                0.30
# 10          (arroz)        (feijao)                0.25                0.25
# 11         (feijao)         (arroz)                0.25                0.25
# 12   (refrigerante)       (cerveja)                0.20                0.25
# 13        (cerveja)  (refrigerante)                0.25                0.20
# 14    (acucar, pao)          (cafe)                0.20                0.40
# 15   (acucar, cafe)           (pao)                0.30                0.40
# 16      (pao, cafe)        (acucar)                0.30                0.30
# 17         (acucar)     (pao, cafe)                0.30                0.30
# 18   (acucar, cafe)         (leite)                0.30                0.35
# 19  (acucar, leite)          (cafe)                0.20                0.40
# 20    (cafe, leite)        (acucar)                0.25                0.30
# 21         (acucar)   (cafe, leite)                0.30                0.25
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0      0.25    0.625000  1.785714               1.0    0.1100    1.733333
# 1      0.25    0.714286  1.785714               1.0    0.1100    2.100000
# 2      0.30    0.750000  1.875000               1.0    0.1400    2.400000
# 3      0.30    0.750000  1.875000               1.0    0.1400    2.400000
# 4      0.20    0.666667  1.666667               1.0    0.0800    1.800000
# 5      0.25    0.625000  1.785714               1.0    0.1100    1.733333
# 6      0.25    0.714286  1.785714               1.0    0.1100    2.100000
# 7      0.20    0.666667  1.904762               1.0    0.0950    1.950000
# 8      0.30    1.000000  2.500000               1.0    0.1800         inf
# 9      0.30    0.750000  2.500000               1.0    0.1800    2.800000
# 10     0.25    1.000000  4.000000               1.0    0.1875         inf
# 11     0.25    1.000000  4.000000               1.0    0.1875         inf
# 12     0.20    1.000000  4.000000               1.0    0.1500         inf
# 13     0.20    0.800000  4.000000               1.0    0.1500    4.000000
# 14     0.20    1.000000  2.500000               1.0    0.1200         inf
# 15     0.20    0.666667  1.666667               1.0    0.0800    1.800000
# 16     0.20    0.666667  2.222222               1.0    0.1100    2.100000
# 17     0.20    0.666667  2.222222               1.0    0.1100    2.100000
# 18     0.20    0.666667  1.904762               1.0    0.0950    1.950000
# 19     0.20    1.000000  2.500000               1.0    0.1200         inf
# 20     0.20    0.800000  2.666667               1.0    0.1250    3.500000
# 21     0.20    0.666667  2.666667               1.0    0.1250    2.250000
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 0        0.733333  0.500000   0.423077    0.669643
# 1        0.676923  0.500000   0.523810    0.669643
# 2        0.777778  0.600000   0.583333    0.750000
# 3        0.777778  0.600000   0.583333    0.750000
# 4        0.571429  0.400000   0.444444    0.583333
# 5        0.733333  0.500000   0.423077    0.669643
# 6        0.676923  0.500000   0.523810    0.669643
# 7        0.678571  0.444444   0.487179    0.619048
# 8        0.857143  0.750000   1.000000    0.875000
# 9        1.000000  0.750000   0.642857    0.875000
# 10       1.000000  1.000000   1.000000    1.000000
# 11       1.000000  1.000000   1.000000    1.000000
# 12       0.937500  0.800000   1.000000    0.900000
# 13       1.000000  0.800000   0.750000    0.900000
# 14       0.750000  0.500000   1.000000    0.750000
# 15       0.571429  0.400000   0.444444    0.583333
# 16       0.785714  0.500000   0.523810    0.666667
# 17       0.785714  0.500000   0.523810    0.666667
# 18       0.678571  0.444444   0.487179    0.619048
# 19       0.750000  0.500000   1.000000    0.750000
# 20       0.833333  0.571429   0.714286    0.733333
# 21       0.892857  0.571429   0.555556    0.733333

# %%
# Filtrar as regras relevatantes
rules_filtered = rules[
    (rules["lift"] > 1) &
    (rules["confidence"] > 0.6)
].sort_values(by="lift", ascending=False)

print("Regras de associação filtradas")
print(rules_filtered[["antecedents", "consequents", "support", "confidence", "lift"]])
# Out:
# Regras de associação filtradas
#         antecedents     consequents  support  confidence      lift
# 12   (refrigerante)       (cerveja)     0.20    1.000000  4.000000
# 13        (cerveja)  (refrigerante)     0.20    0.800000  4.000000
# 10          (arroz)        (feijao)     0.25    1.000000  4.000000
# 11         (feijao)         (arroz)     0.25    1.000000  4.000000
# 20    (cafe, leite)        (acucar)     0.20    0.800000  2.666667
# 21         (acucar)   (cafe, leite)     0.20    0.666667  2.666667
# 19  (acucar, leite)          (cafe)     0.20    1.000000  2.500000
# 14    (acucar, pao)          (cafe)     0.20    1.000000  2.500000
# 8          (acucar)          (cafe)     0.30    1.000000  2.500000
# 9            (cafe)        (acucar)     0.30    0.750000  2.500000
# 16      (pao, cafe)        (acucar)     0.20    0.666667  2.222222
# 17         (acucar)     (pao, cafe)     0.20    0.666667  2.222222
# 18   (acucar, cafe)         (leite)     0.20    0.666667  1.904762
# 7          (acucar)         (leite)     0.20    0.666667  1.904762
# 2             (pao)          (cafe)     0.30    0.750000  1.875000
# 3            (cafe)           (pao)     0.30    0.750000  1.875000
# 0             (pao)         (leite)     0.25    0.625000  1.785714
# 5            (cafe)         (leite)     0.25    0.625000  1.785714
# 6           (leite)          (cafe)     0.25    0.714286  1.785714
# 1           (leite)           (pao)     0.25    0.714286  1.785714
# 4          (acucar)           (pao)     0.20    0.666667  1.666667
# 15   (acucar, cafe)           (pao)     0.20    0.666667  1.666667
